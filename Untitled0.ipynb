# %%
n=int(input("Hay nhap n: "))
tong = 0
for i in range (1,n+1):
  tong+=i
print("tong tu 1 den n la:", tong)
# Out:
# Hay nhap n: 55
# tong tu 1 den n la: 1540

# %%
i=[]
while len(i)<3:
 t=int(input())
 i.append(t)
print(i)
# Out:
# 3
# 2
# 1
# [3, 2, 1]

# %%
n=int(input("Nhap vao so: "))
if n%2!=0 or n<1:
  print("So khong phai so chan")
else:
  print("So chan")
# Out:
# Nhap vao so: 6
# So chan

# %%
n=int(input("Hay nhap vao so: "))
if str(n)[len(str(n))-1]=="5":
  print("True")
else:
  print("False")
# Out:
# Hay nhap vao so: 423423
# False

# %%
n= int(input("Nhap so a: "))
def So_hople(a):
  if a%5==0 and a%3==0:
    return True
  else:
    return False
if So_hople(n)==True:
  print("So chia het cho ca 3 va 5")
else:
  print("So khong chia het cho ca 3 va 5")
# Out:
# Nhap so a: 45
# So chia het cho ca 3 va 5

# %%
a,b,c=map(int,input("Nhap ngay thang nam sinh theo thu tu: ").split())
def Hop_le(a,b,c):
  if 2025-c<18:
    return False
  elif 2025-c==18 and 12-b>0:
    return False
  elif 2025-c==18 and 12-b==0 and 4-a>0:
    return False
  else:
    return True
if Hop_le(a,b,c)==True:
  print("Ban du tuoi bau cu ")
else:
  print("Ban chua du tuoi bau cu")
# Out:
# Nhap ngay thang nam sinh theo thu tu: 2 12 2006
# Ban du tuoi bau cu

# %%
n=int(input("Hay nhap n:"))
if n>99 or n<1:
  print("So khong phu hop")
else:
  x=1
  for i in range (1,n+1):
   x*=i
  print("Giai thua cua n! la:",x)
# Out:
# Hay nhap n:9
# Giai thua cua n! la: 362880

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
n=int(input("Nhap so n:"))
def so_nguyen_to(x):
   if x<2:
     return False
   for i in range(2,int(x**0.5)+1):
     if x%i==0:
      return False
   return True
t=0
for k in range(1,n):
  if n%k==0 and so_nguyen_to(k)==True:
   t=k
print(t)
# Out:
# Nhap so n:99
# 11

# %%
print("Nhap so n:")
def so_can_tim(x):
  for i in range(1,n+1):
    if type(i**0.5)=int and string:
      return True
for a in range(1,n+1):

# %%
n=int(input("Nhap so n:"))
if n>10**6 or n<1:
  print("So khong phu hop")
else:
  t=0
  for i in range(1,n+1):
    if n%i==0 and i%2==0:
      t+=1
  print("So luong uoc so chan la:",t)
# Out:
# Nhap so n:360
# So luong uoc so chan la: 18

# %%
n=int(input("Nhap so a:"))
m=int(input("Nhap so b:"))
if m>n:
  k=0
  for i in range(1,m+1):
    if m%i==0 and n%i==0:
      k=i
else:
  k=0
  for i in range(1,n+1):
    if m%i==0 and n%i==0:
      k=i
print("So can tim la:",k)
# Out:
# Nhap so a:54353455
# Nhap so b:545345345
# So can tim la: 5

# %%
def Max_of_two(a,b):
  if a>b:
    return a
  else:
    return b
a, b=int(input("Nhap a:")),int(input("Nhap b:"))
print(f"So lon nhat la {Max_of_two(a,b)}")
# Out:
# Nhap a:4
# Nhap b:5
# So lon nhat la 5

# %%
def Tinh_giai_thua(a):
  t=1
  for i in range(1,a+1):
    t*= i
  return t
n=int(input("Nhap n:"))
print(f"Giai thua cua n la: {Tinh_giai_thua(n)}")
# Out:
# Nhap n:9
# Giai thua cua n la: 362880

# %%
def So_nguyen_to(a):
  if a<2:
    return False
  elif a==2:
    return True
  elif a%2==0:
    return False
  else:
    for i in range(2,a):
     if a%i==0:
      return False
  return True
n=int(input("Nhap so n:"))
if So_nguyen_to(n)==True:
  print(f"So cua ban la so nguyen to")
else:
  print("So cua ban khong phai so nguyen to")
# Out:
# Nhap so n:89
# So cua ban la so nguyen to

# %%
nums= list(map(int,input("Nhap cac so: ").split()))
def cac_so_bi_trung(a):
  k=[]
  t=set()
  for i in nums:
    if i in t:
      if i not in k:
        k.append(i)
    else:
      t.add(i)
  return k
print(f"Cac so bi trung la:  {cac_so_bi_trung(nums)}")
solanlap=set()
for i in range(len(list(nums))):
  x= list(nums)[i]
  a=0
  for j in range(len(list(nums))):
    if list(nums)[j]==x:
      a+=1
  if a>1:
   solanlap.add(a)
print(f"So lan lap cua chung lan luot la: {solanlap}")
# Out:
# Nhap cac so: 1 1 1 2 2 3 3 3 3
# Cac so bi trung la:  [1, 2, 3]
# So lan lap cua chung lan luot la: {2, 3, 4}

# %%
n=int(input("Nhap so hang cuoi cua day so: "))
k=int(input("Nhap so k: "))
for i in range(1, n+1):
  if k=i:
   print
    type
# Out:
# Nhap so hang cuoi cua day so: 8
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3269380268.py in <cell line: 0>()
#       2 k=list()
#       3 for i in range(1,n+1):
# ----> 4   k=list(i)
#
# TypeError: 'int' object is not iterable

# %%
n=int(input("Hay nhap so n: "))
if n<0:
  print("So khong hop le")
else:
  k=str(n)
  t=0
  m=0
  for i in range(0,len(k)):
    t=int(k[i])
    m+=t

print(f"Tong cac chu so la: {m}")
# Out:
# Hay nhap so n: 123
# Tong cac chu so la: 6

# %%
#Neu la phep chia,so bi chia nhap truoc
#Neu la phep tru,so bi tru nhap truoc
a,b=map(int,input("Nhap 2  so: ").split())
t=print("Hay nhap dau cua phep tinh voi 2 so tren: ")
def May_tinh(a,b):
  if t=="+":
    return a+b
  if t=="-":
    return a-b
  if t=="*":
    return a*b
  if t=="/":
    return a/b
print(f"Ket qua cua phep tinh la: {May_tinh(a,b)}")
# Out:
# Nhap 2  so: 3 2
# Hay nhap dau cua phep tinh voi 2 so tren:
# Ket qua cua phep tinh la: None
